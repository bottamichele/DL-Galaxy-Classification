# %% [markdown]
# # Import

# %%
from torchsummary import summary
from xception import Xception

# %%
xception_model = Xception(6)

# %%
summary(xception_model, (3, 128, 128), batch_size=64)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [64, 32, 64, 64]             896
#        BatchNorm2d-2           [64, 32, 64, 64]              64
#               ReLU-3           [64, 32, 64, 64]               0
#             Conv2d-4           [64, 64, 64, 64]          18,496
#        BatchNorm2d-5           [64, 64, 64, 64]             128
#               ReLU-6           [64, 64, 64, 64]               0
#             Conv2d-7          [64, 128, 32, 32]           8,320
#             Conv2d-8          [64, 128, 64, 64]           8,320
#             Conv2d-9          [64, 128, 64, 64]           1,280
#   SeparableConv2d-10          [64, 128, 64, 64]               0
#       BatchNorm2d-11          [64, 128, 64, 64]             256
#              ReLU-12          [64, 128, 64, 64]               0
#            Conv2d-13          [64, 128, 64, 64]          16,512
# ...

# %%
summary(xception_model, (3, 128, 128), batch_size=32)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [32, 32, 64, 64]             896
#        BatchNorm2d-2           [32, 32, 64, 64]              64
#               ReLU-3           [32, 32, 64, 64]               0
#             Conv2d-4           [32, 64, 64, 64]          18,496
#        BatchNorm2d-5           [32, 64, 64, 64]             128
#               ReLU-6           [32, 64, 64, 64]               0
#             Conv2d-7          [32, 128, 32, 32]           8,320
#             Conv2d-8          [32, 128, 64, 64]           8,320
#             Conv2d-9          [32, 128, 64, 64]           1,280
#   SeparableConv2d-10          [32, 128, 64, 64]               0
#       BatchNorm2d-11          [32, 128, 64, 64]             256
#              ReLU-12          [32, 128, 64, 64]               0
#            Conv2d-13          [32, 128, 64, 64]          16,512
# ...

# %%
summary(xception_model, (3, 299, 299), batch_size=1)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1          [1, 32, 150, 150]             896
#        BatchNorm2d-2          [1, 32, 150, 150]              64
#               ReLU-3          [1, 32, 150, 150]               0
#             Conv2d-4          [1, 64, 150, 150]          18,496
#        BatchNorm2d-5          [1, 64, 150, 150]             128
#               ReLU-6          [1, 64, 150, 150]               0
#             Conv2d-7           [1, 128, 75, 75]           8,320
#             Conv2d-8         [1, 128, 150, 150]           8,320
#             Conv2d-9         [1, 128, 150, 150]           1,280
#   SeparableConv2d-10         [1, 128, 150, 150]               0
#       BatchNorm2d-11         [1, 128, 150, 150]             256
#              ReLU-12         [1, 128, 150, 150]               0
#            Conv2d-13         [1, 128, 150, 150]          16,512
# ...

# %%
summary(xception_model, (3, 224, 224), batch_size=32)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [32, 32, 112, 112]             896
#        BatchNorm2d-2         [32, 32, 112, 112]              64
#               ReLU-3         [32, 32, 112, 112]               0
#             Conv2d-4         [32, 64, 112, 112]          18,496
#        BatchNorm2d-5         [32, 64, 112, 112]             128
#               ReLU-6         [32, 64, 112, 112]               0
#             Conv2d-7          [32, 128, 56, 56]           8,320
#             Conv2d-8        [32, 128, 112, 112]           8,320
#             Conv2d-9        [32, 128, 112, 112]           1,280
#   SeparableConv2d-10        [32, 128, 112, 112]               0
#       BatchNorm2d-11        [32, 128, 112, 112]             256
#              ReLU-12        [32, 128, 112, 112]               0
#            Conv2d-13        [32, 128, 112, 112]          16,512
# ...

# %%
summary(xception_model, (3, 84, 84), batch_size=1)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1            [1, 32, 42, 42]             896
#        BatchNorm2d-2            [1, 32, 42, 42]              64
#               ReLU-3            [1, 32, 42, 42]               0
#             Conv2d-4            [1, 64, 42, 42]          18,496
#        BatchNorm2d-5            [1, 64, 42, 42]             128
#               ReLU-6            [1, 64, 42, 42]               0
#             Conv2d-7           [1, 128, 21, 21]           8,320
#             Conv2d-8           [1, 128, 42, 42]           8,320
#             Conv2d-9           [1, 128, 42, 42]           1,280
#   SeparableConv2d-10           [1, 128, 42, 42]               0
#       BatchNorm2d-11           [1, 128, 42, 42]             256
#              ReLU-12           [1, 128, 42, 42]               0
#            Conv2d-13           [1, 128, 42, 42]          16,512
# ...

# %%
summary(xception_model, (3, 84, 84), batch_size=128)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1          [128, 32, 42, 42]             896
#        BatchNorm2d-2          [128, 32, 42, 42]              64
#               ReLU-3          [128, 32, 42, 42]               0
#             Conv2d-4          [128, 64, 42, 42]          18,496
#        BatchNorm2d-5          [128, 64, 42, 42]             128
#               ReLU-6          [128, 64, 42, 42]               0
#             Conv2d-7         [128, 128, 21, 21]           8,320
#             Conv2d-8         [128, 128, 42, 42]           8,320
#             Conv2d-9         [128, 128, 42, 42]           1,280
#   SeparableConv2d-10         [128, 128, 42, 42]               0
#       BatchNorm2d-11         [128, 128, 42, 42]             256
#              ReLU-12         [128, 128, 42, 42]               0
#            Conv2d-13         [128, 128, 42, 42]          16,512
# ...

# %%
summary(xception_model, (3, 84, 84), batch_size=32)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [32, 32, 42, 42]             896
#        BatchNorm2d-2           [32, 32, 42, 42]              64
#               ReLU-3           [32, 32, 42, 42]               0
#             Conv2d-4           [32, 64, 42, 42]          18,496
#        BatchNorm2d-5           [32, 64, 42, 42]             128
#               ReLU-6           [32, 64, 42, 42]               0
#             Conv2d-7          [32, 128, 21, 21]           8,320
#             Conv2d-8          [32, 128, 42, 42]           8,320
#             Conv2d-9          [32, 128, 42, 42]           1,280
#   SeparableConv2d-10          [32, 128, 42, 42]               0
#       BatchNorm2d-11          [32, 128, 42, 42]             256
#              ReLU-12          [32, 128, 42, 42]               0
#            Conv2d-13          [32, 128, 42, 42]          16,512
# ...
